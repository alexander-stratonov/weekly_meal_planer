# %%
import pandas as pd
import numpy as np

df = pd.read_csv('file1000.csv')
df
# Out:
#                                        name  \
# 0    Макароны с горошком, фетой и семечками
# 1      Кабачок, фаршированный мясом и рисом
# 2                 Печеночный паштет на пару
# 3                         Чизкейк «ШокоШок»
# 4                      Салат "Версальский "
# ..                                      ...
# 995                          Салат "Orange"
# 996                       Фруктовый лимонад
# 997          Дрезденский миндальный штоллен
# 998       Сливочный шоколадно-вишневый торт
# 999                  Рыба с луком и уксусом
#
#                                            ingredients
# 0    {'Макаронные изделия': '200 г', 'Горошек зелен...
# 1    {'Кабачок': '1 шт', 'Филе': '250 г', 'Рис': '0...
# 2    {'Печень куриная': '600 г', 'Морковь': '1 шт',...
# 3    {'Печенье': '90 г', 'Масло сливочное': '70 г',...
# 4    {'Шампиньоны': None, 'Креветки': None, 'Пармез...
# ..                                                 ...
# ...
